# %% [markdown]
# # Aufgabe Teilmodul 2.1
# ## Auswahl Ihrer Daten
# Suchen Sie auf bibsonomy mit einem selbst gewählten Suchbegriff nach Publikationen. Auf Bibsonomy lassen sich die Ergebnisse einer Keyword-Suche (z.B. "Bibliothek") in einer Vielzahl verschiedener Formate exportieren (Limit ggf. vorher auf 1000 erhöhen) und lokal speichern. Geben Sie dafür einen Suchbegriff oben rechts in die Maske ein und bestätigen Sie die Eingabe. Rechts neben der Überschrift der rechten Spalte ("publications"/"Publikationen") klicken Sie ganz rechte auf das Symbol mit dem Pfeil nach rechts, der aus einem Kasten zeigt ("export options for displayed posts"/"Exportieren für angezeigte Einträge"), dann auf mehr/more. Wählen Sie ZUERST bei posts/Einträge "1000" aus, und wählen sie dann in dem Format drop-Down-Menü fast ganz unten JSON aus. Es öffnet sich die JSON Datei in ihrem Browser.  Sie können die URL wie im Tutorial über das requests Modul in Python öffnen.
#
# Alternativ können Sie die Datei auch lokal speichern. Dafür rechtsklicken Sie irgendwo, wählen Sie "save as..."/"speichern unter..." und speichern Sie die Datei unter einem passenden Dateinamen mit der Endung ".json".
#
# Für eine Nutzung im zweiten Modulteil ist ein großer Datensatz sinnvoll. Fügen Sie daher die Ergebnisse mehrerer Suchen mit Pandas in einem Datensatz zusammenführen.
# Fügen sie ihren Datensätzen dabei den Suchterm hinzu, der zu den Ergebnissen geführt hat. Tipp: Informationen dazu finden Sie unter "Daten Verändern und Hinzufügen".
#
# Nutzen sie dabei Python (vorzugsweise in einem Jupyter Notebook) mithilfe von Pandas. Sollten Sie Probleme haben, schauen Sie im Pandas Tutorial unter "JSON einlesen" oder bitten Sie Fabian Haak im Moodle Austauschforum um Hilfe.
# Legen Sie Ihr Notebook bzw. Python-Script mit den Lösungen in einem "Modul_2-1" Ordner im eigenen Repositorium auf GitHub ab. Fügen Sie mich als zusätzlichen Collaborator (GitHub-Name: HaakFab) hinzu, so kann ich besser Feedback oder Hilfestellungen geben.
#
# ## Exportformat erstellen
# Diese Aufgabe dient als direkte Vorbereitung des nächsten Modulteils. Wir empfehlen, Pandas für die Bearbeitung der Aufgabe zu nutzen.
#
# ### Datenaufbereitung
# Für den nächsten Teil dieses Modules möchten wir unseren Datensatz wieder als JSON-File ablegen. Zunächst möchten wir aber die Bibsonomy-Daten noch etwas zu bereinigen:
# - Filtern Sie die Daten so, dass nur noch Einträge des Typs "Publication" enthalten sind.
# - Überlegen Sie, welche Felder Sie möglicherweise umbenennen wollen, und welche Sie nicht benötigen. Benennen Sie entsprechend um und wählen Sie nur die Spalten, die für Sie sinnvolle Informationen enthalten. Mögliche Änderungen der Daten sind das Umbenennen von Felder zu eindeutigeren Bezeichnungen (wie beispielsweise im Pandas Tutorial "label" zu "title"). Filtern Sie ihre Daten jedoch nicht zu drastisch und entfernen Sie nicht zu viele Felder, damit im zweiten Modulteil noch genügend Informationen übrig bleiben.
# - Wenn sie mehrere Suchergebnisse zusammengeführt haben, ist es sinnvoll, Nachduplikaten zu überprüfen.
# - BONUS: Wie bei den Jareszahlen ist es durchaus sinnvoll, zu überprüfen, ob alle Einträge "sauber" vorliegen. Stellen sie dafür sicher, dass alle Einträge Informationen zu Titel, AutorInnen und Veröffentlichungsjahr enthalten und dass das Jahr eine sinnvolle Zahl ist!
# Daten Export
#
# ### Erstellen Sie einen sauberen Export im JSON-Format, das von Solr akzeptiert wird.
#
# Für die Weiterverwendung ist nicht relevant, wie die einzelnen Felder benannt sind oder wie viele Felder es gibt, Es ist aber entscheidend, dass die äußere Form einer Liste von Dictionaries gewahrt wird. (HINWEIS BEI PROBLEMEN: Schauen Sie im Pandas Tutorial unter "Export als JSON")

# %%
import pandas as pd
import requests

# zum Zusammenbauen der Bibsonomy URL brauchen wir alles, was vor und nach der Query kommt
url_base = "https://www.bibsonomy.org/json/search/"
url_attr = "?items=1000"

def df_from_query(query):
    # die URL; wir müssen Leerzeichen ersetzen mit "%20" nach ASCII Encoding guideline
    url = url_base + query.replace(" ", "%20") + url_attr
    
    result = requests.get(url)
    json_data = result.json()
    
    # im Feld "items" stecken die relevanten Dateneinträge
    dataframe = pd.DataFrame(json_data["items"])

    # wir filtern so, dass nur Publikationen bleiben
    dataframe.loc[dataframe["type"] == "Publication"]

    # wir möchten die query in die Daten eintragen 
    dataframe["query"] = query
    
    # die Rückgabe der Methode nicht vergessen:
    return dataframe

# wir erstellen eine leere Liste, in die wir unsere Dataframes packen
dataframes = []

# eine Liste von Suchanfragen
queries = ["artificial intelligence", "AI", "machine learning", "language model", "KI", "künstliche intelligenz", "maschinelles lernen", "sprachmodell"]

# jetzt gehen wir die Liste von Suchanfragen durch und rufen unsere Funktion für jede Suchanfrage auf
for query in queries:
    df = df_from_query(query)
    # schließlich fügen wir das DataFrame über append unserer Liste von Dataframes hinzu
    dataframes.append(df)

    # wie wir uns eine Statusausgabe schreiben würden:
    # print("Ergebnisse für ", query , " gefunden. Dataframe enthält ",len(df), " Einträge.")
    
    # mit einem f String lassen sich Variablen in Strings viel einfacher formatieren:
    print(f"{len(df)} Ergebnisse für query {query} gefunden.")
# Out:
# 2000 Ergebnisse für query artificial intelligence gefunden.
# 2000 Ergebnisse für query AI gefunden.
# 2000 Ergebnisse für query machine learning gefunden.
# 1311 Ergebnisse für query language model gefunden.
# 1410 Ergebnisse für query KI gefunden.
# 1275 Ergebnisse für query künstliche intelligenz gefunden.
# 295 Ergebnisse für query maschinelles lernen gefunden.
# 30 Ergebnisse für query sprachmodell gefunden.

# %%
# Da die dataframes die selbe From (column titles sind identisch, wenn für alle vorhanden) haben, können wir die Dataframes über concat zusammenfügen
data_conc = pd.concat(dataframes, ignore_index=True)

# %%
data_conc
# Out:
#               type                                                 id  \
# 0         Bookmark  https://www.bibsonomy.org/url/0791349ca5df61f2...
# 1         Bookmark  https://www.bibsonomy.org/url/ab1853d0737e8f05...
# 2         Bookmark  https://www.bibsonomy.org/url/fefff0a869d99d49...
# 3         Bookmark  https://www.bibsonomy.org/url/11ed70d879ab786e...
# 4         Bookmark  https://www.bibsonomy.org/url/0bc655fb81b41240...
# ...            ...                                                ...
# 10316  Publication  https://www.bibsonomy.org/bibtex/271e581fd15fe...
# 10317  Publication  https://www.bibsonomy.org/bibtex/245b6096a3aea...
# 10318  Publication  https://www.bibsonomy.org/bibtex/2ff8060193b4f...
# 10319  Publication  https://www.bibsonomy.org/bibtex/2c54e4fa05955...
# 10320  Publication  https://www.bibsonomy.org/bibtex/2faef6a1c8362...
#
#                                                     tags  \
# 0          [compare, Studium, ai, vergleich, master, ki]
# 1      [robotics, artificial_intelligence, European_C...
# 2                               [Künstliche_Intelligenz]
# 3      [ethics, machinelearning, learninganalytics, h...
# 4      [reinforcement-learning, lecture, 2021, google...
# ...                                                  ...
# 10316                                             [dblp]
# 10317                                             [dblp]
# 10318                                [konstruktionismus]
# 10319                 [kuenstliche_intelligenz, chatgpt]
# 10320  [Künstliche_Intelligenz, Schulunterricht, Chat...
#
#                               intraHash  \
# 0      0791349ca5df61f2f740f401805d0b96
# 1      ab1853d0737e8f0565b737463d7d05ed
# 2      fefff0a869d99d49250edf73ee38ff46
# 3      11ed70d879ab786edaf38b4a41db3277
# 4      0bc655fb81b41240a277d51462058519
# ...                                 ...
# 10316  71e581fd15fe05a3dbc2ab367006b96a
# 10317  45b6096a3aeafd1a21083e34606b920a
# 10318  ff8060193b4f82c31343e6bf2e59094c
# 10319  c54e4fa05955e7b9703e338e7f840126
# 10320  faef6a1c8362cfceab7588b162f68c8c
#
#                                                    label       user  \
# 0      Best Masters of Science (MScs) in Artificial I...      hotho
# 1      Artificial Intelligence | Shaping Europe’s dig...  meneteqel
# 2      Artificial Intelligence market size 2030 | Sta...    schrang
# 3      Artificial Intelligence in Higher Education – ...     ereidt
# 4      Evolution, rewards, and artificial intelligenc...    analyst
# ...                                                  ...        ...
# 10316  Entwicklung und Formalisierung eines objektori...       dblp
# 10317  Spracherkennung mit TANGORA: Medizinische Spra...       dblp
# 10318  Kognition und soziale Praxis : der Soziale Kon...     lepsky
# 10319  ChatGPT und der Unterschied zwischen Form und ...     lepsky
# 10320  Chatbots im Schulunterricht: Wir testen das Fo...  meneteqel
#
#                                              description                 date  \
# 0      Contact Schools Directly - Compare 27 Masters ...  2019-08-16 18:14:29
# 1      The European Commission puts forward a Europea...  2020-02-20 10:38:30
# 2      According to Next Move Strategy Consulting the...  2024-04-29 23:14:00
# 3      “The Promise and Peril of Artificial Intellige...  2018-08-26 11:31:16
# 4      A paper by DeepMind scientist triggered much d...  2021-06-25 17:04:28
# ...                                                  ...                  ...
# 10316                                                     2021-07-17 00:00:00
# 10317                                                     2019-06-21 00:00:00
# 10318                                                     2022-10-20 16:58:49
# 10319                                                     2023-08-28 10:40:47
# 10320                                                     2024-12-17 13:58:46
#
#                 changeDate  count  ... partneroptique openaccess wpoptique  \
# 0      2019-08-16 18:14:29      1  ...            NaN        NaN       NaN
# 1      2020-02-20 10:38:30      1  ...            NaN        NaN       NaN
# 2      2025-01-10 07:02:10      1  ...            NaN        NaN       NaN
# 3      2018-08-26 11:42:28      1  ...            NaN        NaN       NaN
# 4      2021-06-25 17:04:38      1  ...            NaN        NaN       NaN
# ...                    ...    ...  ...            ...        ...       ...
# 10316  2024-04-09 08:41:38      2  ...            NaN        NaN       NaN
# 10317  2019-06-22 11:38:38      1  ...            NaN        NaN       NaN
# 10318  2022-10-20 17:00:03      1  ...            NaN        NaN       NaN
# 10319  2024-09-24 14:51:24      1  ...            NaN        NaN       NaN
# 10320  2024-12-17 13:58:46      2  ...            NaN        NaN       NaN
#
#       bdsk-url-2 read md5sum citations pdfmeat citedbyid mailhosts
# 0            NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 1            NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 2            NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 3            NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 4            NaN  NaN    NaN       NaN     NaN       NaN       NaN
# ...          ...  ...    ...       ...     ...       ...       ...
# 10316        NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 10317        NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 10318        NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 10319        NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 10320        NaN  NaN    NaN       NaN     NaN       NaN       NaN
#
# [10321 rows x 221 columns]

# %% [markdown]
# #### Filtern Sie die Daten so, dass nur noch Einträge des Typs "Publication" enthalten sind.

# %%
data = data_conc.loc[data_conc["type"] == "Publication"]

# %%
[data_conc["type"] == "Publication"]
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  10316     True
#  10317     True
#  10318     True
#  10319     True
#  10320     True
#  Name: type, Length: 10321, dtype: bool]

# %%
data
# Out:
#               type                                                 id  \
# 1000   Publication  https://www.bibsonomy.org/bibtex/24e338b04bc2a...
# 1001   Publication  https://www.bibsonomy.org/bibtex/283c4174f111d...
# 1002   Publication  https://www.bibsonomy.org/bibtex/29f3b59303571...
# 1003   Publication  https://www.bibsonomy.org/bibtex/2a97c2267cfe4...
# 1004   Publication  https://www.bibsonomy.org/bibtex/2df98b0d20723...
# ...            ...                                                ...
# 10316  Publication  https://www.bibsonomy.org/bibtex/271e581fd15fe...
# 10317  Publication  https://www.bibsonomy.org/bibtex/245b6096a3aea...
# 10318  Publication  https://www.bibsonomy.org/bibtex/2ff8060193b4f...
# 10319  Publication  https://www.bibsonomy.org/bibtex/2c54e4fa05955...
# 10320  Publication  https://www.bibsonomy.org/bibtex/2faef6a1c8362...
#
#                                                     tags  \
# 1000                                           [710-714]
# 1001   [digitalisation, artificial_intelligence, soci...
# 1002    [Artificial, Intelligence, Risks, and, Benefits]
# 1003   [industry, artificial_intelligence, health_and...
# 1004   [Human, Intelligence,, intelligence,, centric,...
# ...                                                  ...
# 10316                                             [dblp]
# 10317                                             [dblp]
# 10318                                [konstruktionismus]
# 10319                 [kuenstliche_intelligenz, chatgpt]
# 10320  [Künstliche_Intelligenz, Schulunterricht, Chat...
#
#                               intraHash  \
# 1000   4e338b04bc2abafd9fa0a1f4fe79103a
# 1001   83c4174f111d968e8ca51b252f8fea3e
# 1002   9f3b593035714a894c265f4fb9c535e7
# 1003   a97c2267cfe4a39d368f1507149affd0
# 1004   df98b0d20723566bfc445b3da9e69ac2
# ...                                 ...
# 10316  71e581fd15fe05a3dbc2ab367006b96a
# 10317  45b6096a3aeafd1a21083e34606b920a
# 10318  ff8060193b4f82c31343e6bf2e59094c
# 10319  c54e4fa05955e7b9703e338e7f840126
# 10320  faef6a1c8362cfceab7588b162f68c8c
#
#                                                    label       user  \
# 1000              Artificial Intelligence in Agriculture     ijtsrd
# 1001         Artificial intelligence, labour and society  meneteqel
# 1002           Artificial Intelligence Benefit and Risks     ijtsrd
# 1003   Artificial intelligence in Industry 4.0: Impli...  meneteqel
# 1004   Evolution of Artificial Intelligence by Prompt...     ijtsrd
# ...                                                  ...        ...
# 10316  Entwicklung und Formalisierung eines objektori...       dblp
# 10317  Spracherkennung mit TANGORA: Medizinische Spra...       dblp
# 10318  Kognition und soziale Praxis : der Soziale Kon...     lepsky
# 10319  ChatGPT und der Unterschied zwischen Form und ...     lepsky
# 10320  Chatbots im Schulunterricht: Wir testen das Fo...  meneteqel
#
#       description                 date           changeDate  count  ...  \
# 1000               2021-04-13 13:15:04  2021-04-13 13:15:04      1  ...
# 1001               2024-04-08 09:45:09  2024-04-08 09:46:54      1  ...
# 1002               2020-05-14 10:40:49  2020-05-14 10:40:49      1  ...
# 1003               2024-08-01 15:21:53  2024-08-01 15:21:53      2  ...
# 1004               2024-12-30 07:46:23  2024-12-30 07:46:23      1  ...
# ...           ...                  ...                  ...    ...  ...
# 10316              2021-07-17 00:00:00  2024-04-09 08:41:38      2  ...
# 10317              2019-06-21 00:00:00  2019-06-22 11:38:38      1  ...
# 10318              2022-10-20 16:58:49  2022-10-20 17:00:03      1  ...
# 10319              2023-08-28 10:40:47  2024-09-24 14:51:24      1  ...
# 10320              2024-12-17 13:58:46  2024-12-17 13:58:46      2  ...
#
#       partneroptique openaccess wpoptique bdsk-url-2 read md5sum citations  \
# 1000             NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 1001             NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 1002             NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 1003             NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 1004             NaN        NaN       NaN        NaN  NaN    NaN       NaN
# ...              ...        ...       ...        ...  ...    ...       ...
# 10316            NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 10317            NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 10318            NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 10319            NaN        NaN       NaN        NaN  NaN    NaN       NaN
# 10320            NaN        NaN       NaN        NaN  NaN    NaN       NaN
#
#       pdfmeat citedbyid mailhosts
# 1000      NaN       NaN       NaN
# 1001      NaN       NaN       NaN
# 1002      NaN       NaN       NaN
# 1003      NaN       NaN       NaN
# 1004      NaN       NaN       NaN
# ...       ...       ...       ...
# 10316     NaN       NaN       NaN
# 10317     NaN       NaN       NaN
# 10318     NaN       NaN       NaN
# 10319     NaN       NaN       NaN
# 10320     NaN       NaN       NaN
#
# [6219 rows x 221 columns]

# %% [markdown]
# #### Überlegen Sie, welche Felder Sie möglicherweise umbenennen wollen, und welche Sie nicht benötigen.

# %%
data.columns.to_list()
# Out:
# ['type',
#  'id',
#  'tags',
#  'intraHash',
#  'label',
#  'user',
#  'description',
#  'date',
#  'changeDate',
#  'count',
#  'url',
#  'interHash',
#  'pub-type',
#  'journal',
#  'year',
#  'author',
#  'authors',
#  'editor',
#  'editors',
#  'volume',
#  'number',
#  'pages',
#  'abstract',
#  'ee',
#  'language',
#  'issn',
#  'bibtexKey',
#  'publisher',
#  'address',
#  'isbn',
#  'file',
#  'urldate',
#  'series',
#  'refid',
#  'note',
#  'doi',
#  'shorttitle',
#  'booktitle',
#  'location',
#  'ean',
#  'asin',
#  'dewey',
#  'numpages',
#  'issue_date',
#  'acmid',
#  'owner',
#  'pmid',
#  'timestamp',
#  'username',
#  'intrahash',
#  'added-at',
#  'numer',
#  'interhash',
#  'biburl',
#  'groups',
#  'notes',
#  'size',
#  'citeulike-article-id',
#  'priority',
#  'comment',
#  'book',
#  'date-modified',
#  '_originaltype',
#  '_keywords',
#  '_originalcomment',
#  'eventtitle',
#  'eventdate',
#  'googleid',
#  'cluster',
#  'citeseer-isreferencedby',
#  'rights',
#  'oai',
#  'serial',
#  'articleno',
#  'pagetotal',
#  'ppn_gvk',
#  'subtitle',
#  'local-url',
#  'oldnote',
#  'posted-at',
#  'date-added',
#  'uri',
#  'pii',
#  'affiliation',
#  'rating',
#  'eprint',
#  'lastchecked',
#  'source',
#  'archiveprefix',
#  'primaryclass',
#  'citeulike-linkout-9',
#  'citeulike-linkout-5',
#  'citeulike-linkout-6',
#  'citeulike-linkout-7',
#  'citeulike-linkout-8',
#  'citeulike-linkout-1',
#  'citeulike-linkout-2',
#  'citeulike-linkout-3',
#  'citeulike-linkout-4',
#  'citeulike-linkout-0',
#  'citeulike-linkout-10',
#  'citeulike-linkout-11',
#  'publisher_address',
#  'venue',
#  'imtm-standort',
#  'imtm-signatur',
#  'imtm-fullref',
#  'imtm-code',
#  'imtm-inventarnummer',
#  'copyright',
#  'bdsk-url-1',
#  'annotation',
#  'subject',
#  'bibsource',
#  'identifier',
#  'format',
#  'review',
#  'email',
#  'topic',
#  'xref',
#  'supervisor',
#  'journaltitle',
#  'doc-delivery-number',
#  'number-of-cited-references',
#  'unique-id',
#  'paperid',
#  'text',
#  'folder',
#  'conference',
#  'imtm-stichworte',
#  'imtm-auswahlen',
#  'keyword',
#  'issue',
#  'nocites',
#  'bdsk-file-1',
#  'optvolume',
#  'position',
#  'category',
#  'impact',
#  'quartile',
#  'dnbtitleid',
#  'pdf',
#  'broken',
#  'organisation',
#  'citedreferences',
#  'optseries',
#  'query',
#  'shop',
#  'sortdate',
#  'isbn10',
#  'article-number',
#  'url_ppt',
#  'url_slides',
#  'page',
#  'audit-trail',
#  'lccn',
#  'addendum',
#  'pubmedid',
#  'abstractnote',
#  'place',
#  'collection',
#  'adsurl',
#  'adsnote',
#  'mrclass',
#  'mrnumber',
#  'mrnumber-url',
#  'bibdate',
#  'acknowledgement',
#  'reviewer',
#  'coden',
#  'mendeley-tags',
#  'arxivid',
#  'citeseerurl',
#  'library',
#  'file-x',
#  'codeurl',
#  'pmcid',
#  'fjournal',
#  'hdsurl',
#  'uniqueid',
#  'xcrossref',
#  'titleaddon',
#  'booktitleadon',
#  'funding-acknowledgement',
#  'journal-iso',
#  'author-email',
#  'keywords-plus',
#  'subject-category',
#  'funding-text',
#  'times-cited',
#  'hal_id',
#  'audience',
#  'elocation-id',
#  'optcrossref',
#  'presentation_start',
#  'session',
#  'track',
#  'presentation_end',
#  'room',
#  'eid',
#  'cdrom',
#  'revision',
#  'price',
#  'translator',
#  'keywords',
#  'intext',
#  'collaborator',
#  'vgwort',
#  'entrytype',
#  'author+an',
#  'yearoptique',
#  'partneroptique',
#  'openaccess',
#  'wpoptique',
#  'bdsk-url-2',
#  'read',
#  'md5sum',
#  'citations',
#  'pdfmeat',
#  'citedbyid',
#  'mailhosts']

# %%
data_sel = data [[
    "id", 
    "label", 
    
]]

# %% [markdown]
# #### Benennen Sie entsprechend um und wählen Sie nur die Spalten, die für Sie sinnvolle Informationen enthalten. Mögliche Änderungen der Daten sind das Umbenennen von Felder zu eindeutigeren Bezeichnungen (wie beispielsweise im Pandas Tutorial "label" zu "title").

# %% [markdown]
# #### Wenn sie mehrere Suchergebnisse zusammengeführt haben, ist es sinnvoll, nach Duplikaten zu überprüfen.

# %% [markdown]
# #### SABINE:
# - Sollte man Dublikate vor dem Merge entfernen lassen oder lieber danach?

# %% [markdown]
# #### BONUS: Wie bei den Jareszahlen ist es durchaus sinnvoll, zu überprüfen, ob alle Einträge "sauber" vorliegen. Stellen sie dafür sicher, dass alle Einträge Informationen zu Titel, AutorInnen und Veröffentlichungsjahr enthalten und dass das Jahr eine sinnvolle Zahl ist!

# %% [markdown]
# ### Wenn noch Zeit ist (sonst: wird nachgereicht!)
#
# #### LARA:
# - habe bei der Autoren-Spalte alle NaN Einträge rausgelöscht später aber festgestellt, dass ich noch solche Einträge habe: [?]
# Wie könnte ich diese rausfiltern und löschen sodass ich am Ende nur Namen in der Spalte habe?
# - in der Spalte "language" hatte ich Titel auf deutsch und englisch. Deutsche Titel hatten bspws. folgende Werte: dt, ger, german
# Wie kann ich diese Werte alle in "deutsch" umbenennen?
#
#
#
# 1. Language Spalte säubern --> nur noch EN oder DE als Werte! Bei keiner angabe EN eintragen

# %% [markdown]
# ## PAUSE

# %% [markdown]
# # Gruppenaufgabe 1
# ### Aufgabenbeschreibung
# Wir möchten nun zusätzlich zu den Bibsonomy Daten auch noch Daten aus einer weiteren Quelle zusammenführen, in diesem Fall Semantic Scholar.
#
# 1. Lade "bibsonomy.json" und "semantic_scholar.json" in Pandas als ein Dataframe, füge eine Spalte "source" hinzu, in der du festhälst, woher die Suchergebnisse kommen  (also: bibsonomy oder semantic_scholar).
# 2. Selektiere und benenne die Spalten so um, dass aus beiden Quellen Titel, Autoren, URL, Abstract, Keywords, Query (Suchanfrage) sowie das Jahr enthalten und gleich benannt sind.
# 3. Stelle sicher, dass die Autoren gleich als Liste formatiert sind (also z. B. [Max Mustermann, Lieschen Müller] oder [Mustermann M., Müller L.]).
# 4. Führe die Datensätze zusammen.
# 5. Stelle sicher, dass alle Einträge für "Jahr" eine 4-stellige Zahl (int) sind.
# 6. Entferne Duplikate (anhand der Spalte Title).
# 7. Sorge dafür, dass es einen durchgängigen Index gibt.

# %%
import pandas as pd

# %%
df_bibsonomy = pd.read_json("bibsonomy.json")
df_bibsonomy["source"] = "bibsonomy"
df_bibsonomy
# Out:
#                                                      id  \
# 1000  https://www.bibsonomy.org/bibtex/24e338b04bc2a...
# 1001  https://www.bibsonomy.org/bibtex/29f3b59303571...
# 1002  https://www.bibsonomy.org/bibtex/24bc08fb79365...
# 1003  https://www.bibsonomy.org/bibtex/29f87881e4dec...
# 1004  https://www.bibsonomy.org/bibtex/263320f0ab96a...
# ...                                                 ...
# 7271  https://www.bibsonomy.org/bibtex/2521eb5477437...
# 7272  https://www.bibsonomy.org/bibtex/2521eb5477437...
# 7273  https://www.bibsonomy.org/bibtex/26b29953c87a0...
# 7274  https://www.bibsonomy.org/bibtex/2b1b8a871f03e...
# 7275  https://www.bibsonomy.org/bibtex/2fc318678d505...
#
#                                                    tags  \
# 1000                                          [710-714]
# 1001   [Artificial, Intelligence, Risks, and, Benefits]
# 1002  [ANN, Fuzzylogic, ElectricalEngineering, Artif...
# 1003  [Artificial, Intelligence, Markup, Chatbot, La...
# 1004  [Learning,, Systems,, Artificialintelligence, ...
# ...                                                 ...
# 7271                                             [LSAP]
# 7272                                     [deepMatching]
# 7273                                             [dblp]
# 7274                                             [dblp]
# 7275                                             [dblp]
#
#                         query  \
# 1000  artificial intelligence
# 1001  artificial intelligence
# 1002  artificial intelligence
# 1003  artificial intelligence
# 1004  artificial intelligence
# ...                       ...
# 7271           language model
# 7272           language model
# 7273           language model
# 7274           language model
# 7275           language model
#
#                                                   title description  \
# 1000             Artificial Intelligence in Agriculture
# 1001          Artificial Intelligence Benefit and Risks
# 1002           Artificial Intelligence in Power Station
# 1003  Artificial Intelligence Based Training and Pla...
# 1004  The Significance of Artificial Intelligence in...
# ...                                                 ...         ...
# 7271  A Decomposable Attention Model for Natural Lan...
# 7272  A Decomposable Attention Model for Natural Lan...
# 7273  An Efficient Language Model Using Double-Array...
# 7274  Style & Topic Language Model Adaptation Using ...
# 7275  Towards Model Driven Architectures for Human L...
#
#                     date                                                url  \
# 1000 2021-04-13 13:15:04  https://www.ijtsrd.com/engineering/electrical-...
# 1001 2020-05-14 10:40:49  https://www.ijtsrd.com/computer-science/artifi...
# 1002 2020-01-10 09:23:37  https://www.ijtsrd.com/engineering/electrical-...
# 1003 2019-03-26 12:35:44  http://www.ijtsrd.com/computer-science/artific...
# 1004 2023-10-14 13:59:49  https://www.ijtsrd.com/computer-science/artifi...
# ...                  ...                                                ...
# 7271 2019-02-19 13:56:10  http://dblp.uni-trier.de/db/journals/corr/corr...
# 7272 2018-08-02 21:36:31  http://dblp.uni-trier.de/db/journals/corr/corr...
# 7273 2019-09-11 00:00:00  http://dblp.uni-trier.de/db/conf/emnlp/emnlp20...
# 7274 2019-09-13 00:00:00  http://dblp.uni-trier.de/db/conf/emnlp/emnlp20...
# 7275 2018-05-25 00:00:00  http://dblp.uni-trier.de/db/conf/coling/oiaf4h...
#
#       year                                             author  \
# 1000  2021  [Matthew N. O. Sadiku, Sarhan M. Musa, Abayomi...
# 1001  2020                                 [Seeta M. Chauhan]
# 1002  2019  [P. Naveen, S. Nikitha, P. Sudeesh, V. Vaishnavi]
# 1003  2018  [Krishanu Deb, Pankaj Agrawal, Harish Nawale, ...
# 1004  2023                            [Dr. Atul Kumar Mishra]
# ...    ...                                                ...
# 7271  2016  [Ankur P. Parikh, Oscar Täckström, Dipanjan Da...
# 7272  2016  [Ankur P. Parikh, Oscar Täckström, Dipanjan Da...
# 7273  2013  [Makoto Yasuhara, Toru Tanaka, Jun ya Norimats...
# 7274  2006                 [Bo-June Paul Hsu, James R. Glass]
# 7275  2014  [Alessandro Di Bari, Guido Vetere, Kateryna Ty...
#
#                                                 authors  text      pages  \
# 1000  [{'first': 'Matthew N. O. Sadiku | Sarhan M. M...  None    710-714
# 1001         [{'first': 'Seeta M.', 'last': 'Chauhan'}]  None  1007-1009
# 1002  [{'first': 'P. Naveen | S. Nikitha | P. Sudees...  None  1020-1025
# 1003  [{'first': 'Krishanu Deb | Pankaj Agrawal | Ha...  None  1057-1060
# 1004    [{'first': 'Dr. Atul Kumar', 'last': 'Mishra'}]  None    786-788
# ...                                                 ...   ...        ...
# 7271  [{'first': 'Ankur P.', 'last': 'Parikh'}, {'fi...  None       None
# 7272  [{'first': 'Ankur P.', 'last': 'Parikh'}, {'fi...  None       None
# 7273  [{'first': 'Makoto', 'last': 'Yasuhara'}, {'fi...  None    222-232
# 7274  [{'first': 'Bo-June Paul', 'last': 'Hsu'}, {'f...  None    373-381
# 7275  [{'first': 'Alessandro Di', 'last': 'Bari'}, {...  None      23-33
#
#                                                abstract     source
# 1000  Artificial Intelligence is one of the emerging...  bibsonomy
# 1001  this article demonstrate Disadvantage of artif...  bibsonomy
# 1002  With increased competitiveness in power genera...  bibsonomy
# 1003  Training and placement cell in colleges is to ...  bibsonomy
# 1004  In an increasingly digitalized world, the util...  bibsonomy
# ...                                                 ...        ...
# 7271                                               None  bibsonomy
# 7272                                               None  bibsonomy
# 7273                                               None  bibsonomy
# 7274                                               None  bibsonomy
# 7275                                               None  bibsonomy
#
# [3779 rows x 14 columns]

# %%
df_bibsonomy_sel = df_bibsonomy[["title", "author", "url", "abstract", "tags", "query", "year"]]
df_bibsonomy_sel
# Out:
#                                                   title  \
# 1000             Artificial Intelligence in Agriculture
# 1001          Artificial Intelligence Benefit and Risks
# 1002           Artificial Intelligence in Power Station
# 1003  Artificial Intelligence Based Training and Pla...
# 1004  The Significance of Artificial Intelligence in...
# ...                                                 ...
# 7271  A Decomposable Attention Model for Natural Lan...
# 7272  A Decomposable Attention Model for Natural Lan...
# 7273  An Efficient Language Model Using Double-Array...
# 7274  Style & Topic Language Model Adaptation Using ...
# 7275  Towards Model Driven Architectures for Human L...
#
#                                                  author  \
# 1000  [Matthew N. O. Sadiku, Sarhan M. Musa, Abayomi...
# 1001                                 [Seeta M. Chauhan]
# 1002  [P. Naveen, S. Nikitha, P. Sudeesh, V. Vaishnavi]
# 1003  [Krishanu Deb, Pankaj Agrawal, Harish Nawale, ...
# 1004                            [Dr. Atul Kumar Mishra]
# ...                                                 ...
# 7271  [Ankur P. Parikh, Oscar Täckström, Dipanjan Da...
# 7272  [Ankur P. Parikh, Oscar Täckström, Dipanjan Da...
# 7273  [Makoto Yasuhara, Toru Tanaka, Jun ya Norimats...
# 7274                 [Bo-June Paul Hsu, James R. Glass]
# 7275  [Alessandro Di Bari, Guido Vetere, Kateryna Ty...
#
#                                                     url  \
# 1000  https://www.ijtsrd.com/engineering/electrical-...
# 1001  https://www.ijtsrd.com/computer-science/artifi...
# 1002  https://www.ijtsrd.com/engineering/electrical-...
# 1003  http://www.ijtsrd.com/computer-science/artific...
# 1004  https://www.ijtsrd.com/computer-science/artifi...
# ...                                                 ...
# 7271  http://dblp.uni-trier.de/db/journals/corr/corr...
# 7272  http://dblp.uni-trier.de/db/journals/corr/corr...
# 7273  http://dblp.uni-trier.de/db/conf/emnlp/emnlp20...
# 7274  http://dblp.uni-trier.de/db/conf/emnlp/emnlp20...
# 7275  http://dblp.uni-trier.de/db/conf/coling/oiaf4h...
#
#                                                abstract  \
# 1000  Artificial Intelligence is one of the emerging...
# 1001  this article demonstrate Disadvantage of artif...
# 1002  With increased competitiveness in power genera...
# 1003  Training and placement cell in colleges is to ...
# 1004  In an increasingly digitalized world, the util...
# ...                                                 ...
# 7271                                               None
# 7272                                               None
# 7273                                               None
# 7274                                               None
# 7275                                               None
#
#                                                    tags  \
# 1000                                          [710-714]
# 1001   [Artificial, Intelligence, Risks, and, Benefits]
# 1002  [ANN, Fuzzylogic, ElectricalEngineering, Artif...
# 1003  [Artificial, Intelligence, Markup, Chatbot, La...
# 1004  [Learning,, Systems,, Artificialintelligence, ...
# ...                                                 ...
# 7271                                             [LSAP]
# 7272                                     [deepMatching]
# 7273                                             [dblp]
# 7274                                             [dblp]
# 7275                                             [dblp]
#
#                         query  year
# 1000  artificial intelligence  2021
# 1001  artificial intelligence  2020
# 1002  artificial intelligence  2019
# 1003  artificial intelligence  2018
# 1004  artificial intelligence  2023
# ...                       ...   ...
# 7271           language model  2016
# 7272           language model  2016
# 7273           language model  2013
# 7274           language model  2006
# 7275           language model  2014
#
# [3779 rows x 7 columns]

# %%
df_semantic_scholar = pd.read_json("semantic_scholar.json")
df_semantic_scholar["source"] = "semantic scholar"
df_semantic_scholar
# Out:
#       index                                   paperId  \
# 0         0  574beee702be3856d60aa482ec725168fe64fc99
# 1         1  e1d2f2a717aa03280126f87c8e5fad695f52bf7c
# 2         2  530a059cb48477ad1e3d4f8f4b153274c8997332
# 3         3  de4b9bc12ddb6b9f6090c032ef5c6290bd64ef36
# 4         4  f134abeaf9bfd41f29b97aec675ec31895bf541d
# ...     ...                                       ...
# 4495   1495  f1a8ff5542ffd51c3618953e5cf926c467154f79
# 4496   1496  591080c335daba2494f18cc04c9f7071501af0eb
# 4497   1497  476029ac9be26bf7f121a388f5c1e45d204efe52
# 4498   1498  b281a9d0c728979f7ffccba1a61d0fc1d29530c1
# 4499   1499  f98e135986414cccf29aec593d547c0656e4d82c
#
#                                             externalIds  \
# 0     {'ArXiv': '2303.12712', 'DBLP': 'journals/corr...
# 1     {'DOI': '10.48047/ijfans/v12/i1/271', 'CorpusI...
# 2     {'ArXiv': '1910.10045', 'DBLP': 'journals/inff...
# 3     {'DBLP': 'conf/bnaic/2017', 'MAG': '2895834617...
# 4     {'MAG': '2908201961', 'DOI': '10.1038/s41591-0...
# ...                                                 ...
# 4495  {'DBLP': 'conf/emnlp/BharadwajMDC16', 'ACL': '...
# 4496  {'MAG': '2017708149', 'DBLP': 'conf/icassp/Ema...
# 4497  {'MAG': '2917128112', 'DBLP': 'journals/corr/a...
# 4498  {'ACL': 'D08-1090', 'MAG': '2116042738', 'DBLP...
# 4499  {'DBLP': 'conf/emnlp/DavisonFR19', 'MAG': '297...
#
#                                        publicationVenue  \
# 0     {'id': '1901e811-ee72-4b20-8f7e-de08cd395a10',...
# 1     {'id': '50c199ea-1ec5-4c24-a902-d9ce8d810efa',...
# 2     {'id': '06afdd0b-0d85-413f-af8a-c3045c12c561',...
# 3     {'id': '82cd90f0-386f-4446-b237-6404c27f6a15',...
# 4     {'id': '9e995b6d-f30b-4ab4-a13b-3dc2cc992f47',...
# ...                                                 ...
# 4495  {'id': '41bf9ed3-85b3-4c90-b015-150e31690253',...
# 4496  {'id': '0d6f7fba-7092-46b3-8039-93458dba736b',...
# 4497  {'id': '1901e811-ee72-4b20-8f7e-de08cd395a10',...
# 4498  {'id': '41bf9ed3-85b3-4c90-b015-150e31690253',...
# 4499  {'id': '41bf9ed3-85b3-4c90-b015-150e31690253',...
#
#                                                     url  \
# 0     https://www.semanticscholar.org/paper/574beee7...
# 1     https://www.semanticscholar.org/paper/e1d2f2a7...
# 2     https://www.semanticscholar.org/paper/530a059c...
# 3     https://www.semanticscholar.org/paper/de4b9bc1...
# 4     https://www.semanticscholar.org/paper/f134abea...
# ...                                                 ...
# 4495  https://www.semanticscholar.org/paper/f1a8ff55...
# 4496  https://www.semanticscholar.org/paper/591080c3...
# 4497  https://www.semanticscholar.org/paper/476029ac...
# 4498  https://www.semanticscholar.org/paper/b281a9d0...
# 4499  https://www.semanticscholar.org/paper/f98e1359...
#
#                                                   title  \
# 0     Sparks of Artificial General Intelligence: Ear...
# 1             Explainable Artificial Intelligence (XAI)
# 2     Explainable Artificial Intelligence (XAI): Con...
# 3                               Artificial Intelligence
# 4     High-performance medicine: the convergence of ...
# ...                                                 ...
# 4495  Phonologically Aware Neural Model for Named En...
# 4496          Large-Scale Distributed Language Modeling
# 4497  BERT for Joint Intent Classification and Slot ...
# 4498  Language and Translation Model Adaptation usin...
# 4499  Commonsense Knowledge Mining from Pretrained M...
#
#                                                abstract  \
# 0     Artificial intelligence (AI) researchers have ...
# 1     Explainable Artificial Intelligence (XAI) has ...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 4495  Named Entity Recognition is a well established...
# 4496  A novel distributed language model that has no...
# 4497  Intent classification and slot filling are two...
# 4498  Traditionally, statistical machine translation...
# 4499  Inferring commonsense knowledge is a key chall...
#
#                                                   venue  year  referenceCount  \
# 0                                             arXiv.org  2023               0
# 1     International Journal of Food and Nutritional ...  2023              33
# 2                                    Information Fusion  2019             430
# 3     Communications in Computer and Information Sci...  2017              27
# 4                                 Nature Network Boston  2019             227
# ...                                                 ...   ...             ...
# 4495  Conference on Empirical Methods in Natural Lan...  2016              39
# 4496  IEEE International Conference on Acoustics, Sp...  2007              12
# 4497                                          arXiv.org  2019              26
# 4498  Conference on Empirical Methods in Natural Lan...  2008              21
# 4499  Conference on Empirical Methods in Natural Lan...  2019              19
#
#       ...  isOpenAccess                                      openAccessPdf  \
# 0     ...          True  {'url': 'http://arxiv.org/pdf/2303.12712', 'st...
# 1     ...          True  {'url': 'https://www.ijfans.org/uploads/paper/...
# 2     ...          True  {'url': 'https://bird.bcamath.org/bitstream/20...
# 3     ...          True                                               None
# 4     ...         False                                               None
# ...   ...           ...                                                ...
# 4495  ...          True  {'url': 'https://www.aclweb.org/anthology/D16-...
# 4496  ...         False                                               None
# 4497  ...         False                                               None
# 4498  ...          True  {'url': 'http://dl.acm.org/ft_gateway.cfm?id=1...
# 4499  ...          True  {'url': 'https://www.aclweb.org/anthology/D19-...
#
#                      fieldsOfStudy              publicationTypes  \
# 0               [Computer Science]              [JournalArticle]
# 1                             None              [JournalArticle]
# 2               [Computer Science]      [JournalArticle, Review]
# 3               [Computer Science]                      [Review]
# 4     [Computer Science, Medicine]      [Review, JournalArticle]
# ...                            ...                           ...
# 4495            [Computer Science]  [JournalArticle, Conference]
# 4496            [Computer Science]  [JournalArticle, Conference]
# 4497            [Computer Science]              [JournalArticle]
# 4498            [Computer Science]  [JournalArticle, Conference]
# 4499            [Computer Science]  [JournalArticle, Conference]
#
#      publicationDate                                            journal  \
# 0         2023-03-22      {'name': 'ArXiv', 'volume': 'abs/2303.12712'}
# 1         2023-10-26  {'name': 'international journal of food and nu...
# 2         2019-10-22  {'name': 'Inf. Fusion', 'pages': '82-115', 'vo...
# 3               None                                  {'volume': '823'}
# 4         2019-01-01  {'name': 'Nature Medicine', 'pages': '44 - 56'...
# ...              ...                                                ...
# 4495      2016-11-01                             {'pages': '1462-1472'}
# 4496      2007-04-15  {'name': '2007 IEEE International Conference o...
# 4497      2019-02-28      {'name': 'ArXiv', 'volume': 'abs/1902.10909'}
# 4498      2008-10-25                               {'pages': '857-866'}
# 4499      2019-09-01      {'name': 'ArXiv', 'volume': 'abs/1909.00505'}
#
#                                          citationStyles  \
# 0     {'bibtex': '@Article{Bubeck2023SparksOA,
#  auth...
# 1     {'bibtex': '@Article{Sewada2023ExplainableAI,
# ...
# 2     {'bibtex': '@Article{Arrieta2019ExplainableAI,...
# 3     {'bibtex': '@Inproceedings{Verheij2017Artifici...
# 4     {'bibtex': '@Article{Topol2019HighperformanceM...
# ...                                                 ...
# 4495  {'bibtex': '@Article{Bharadwaj2016Phonological...
# 4496  {'bibtex': '@Article{Emami2007LargeScaleDL,
#  a...
# 4497  {'bibtex': '@Article{Chen2019BERTFJ,
#  author =...
# 4498  {'bibtex': '@Article{Snover2008LanguageAT,
#  au...
# 4499  {'bibtex': '@Article{Feldman2019CommonsenseKM,...
#
#                                                 authors  \
# 0     [{'authorId': '121645690', 'name': 'Sébastien ...
# 1     [{'authorId': '2151645335', 'name': 'Ranu Sewa...
# 2     [{'authorId': '1379511816', 'name': 'Alejandro...
# 3     [{'authorId': '1697177', 'name': 'Bart Verheij...
# 4       [{'authorId': '144758045', 'name': 'E. Topol'}]
# ...                                                 ...
# 4495  [{'authorId': '2528900', 'name': 'Akash Bharad...
# 4496  [{'authorId': '35797272', 'name': 'Ahmad Emami...
# 4497  [{'authorId': '47261124', 'name': 'Qian Chen'}...
# 4498  [{'authorId': '32278254', 'name': 'M. Snover'}...
# 4499  [{'authorId': '2072080518', 'name': 'Joshua Fe...
#
#                   searchQuery            source
# 0     artificial intelligence  semantic scholar
# 1     artificial intelligence  semantic scholar
# 2     artificial intelligence  semantic scholar
# 3     artificial intelligence  semantic scholar
# 4     artificial intelligence  semantic scholar
# ...                       ...               ...
# 4495     large language model  semantic scholar
# 4496     large language model  semantic scholar
# 4497     large language model  semantic scholar
# 4498     large language model  semantic scholar
# 4499     large language model  semantic scholar
#
# [4500 rows x 22 columns]

# %%
df_semantic_scholar_sel = df_semantic_scholar[["title", "authors", "url", "abstract", "fieldsOfStudy", "searchQuery", "year"]]
df_semantic_scholar_sel
# Out:
#                                                   title  \
# 0     Sparks of Artificial General Intelligence: Ear...
# 1             Explainable Artificial Intelligence (XAI)
# 2     Explainable Artificial Intelligence (XAI): Con...
# 3                               Artificial Intelligence
# 4     High-performance medicine: the convergence of ...
# ...                                                 ...
# 4495  Phonologically Aware Neural Model for Named En...
# 4496          Large-Scale Distributed Language Modeling
# 4497  BERT for Joint Intent Classification and Slot ...
# 4498  Language and Translation Model Adaptation usin...
# 4499  Commonsense Knowledge Mining from Pretrained M...
#
#                                                 authors  \
# 0     [{'authorId': '121645690', 'name': 'Sébastien ...
# 1     [{'authorId': '2151645335', 'name': 'Ranu Sewa...
# 2     [{'authorId': '1379511816', 'name': 'Alejandro...
# 3     [{'authorId': '1697177', 'name': 'Bart Verheij...
# 4       [{'authorId': '144758045', 'name': 'E. Topol'}]
# ...                                                 ...
# 4495  [{'authorId': '2528900', 'name': 'Akash Bharad...
# 4496  [{'authorId': '35797272', 'name': 'Ahmad Emami...
# 4497  [{'authorId': '47261124', 'name': 'Qian Chen'}...
# 4498  [{'authorId': '32278254', 'name': 'M. Snover'}...
# 4499  [{'authorId': '2072080518', 'name': 'Joshua Fe...
#
#                                                     url  \
# 0     https://www.semanticscholar.org/paper/574beee7...
# 1     https://www.semanticscholar.org/paper/e1d2f2a7...
# 2     https://www.semanticscholar.org/paper/530a059c...
# 3     https://www.semanticscholar.org/paper/de4b9bc1...
# 4     https://www.semanticscholar.org/paper/f134abea...
# ...                                                 ...
# 4495  https://www.semanticscholar.org/paper/f1a8ff55...
# 4496  https://www.semanticscholar.org/paper/591080c3...
# 4497  https://www.semanticscholar.org/paper/476029ac...
# 4498  https://www.semanticscholar.org/paper/b281a9d0...
# 4499  https://www.semanticscholar.org/paper/f98e1359...
#
#                                                abstract  \
# 0     Artificial intelligence (AI) researchers have ...
# 1     Explainable Artificial Intelligence (XAI) has ...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 4495  Named Entity Recognition is a well established...
# 4496  A novel distributed language model that has no...
# 4497  Intent classification and slot filling are two...
# 4498  Traditionally, statistical machine translation...
# 4499  Inferring commonsense knowledge is a key chall...
#
#                      fieldsOfStudy              searchQuery  year
# 0               [Computer Science]  artificial intelligence  2023
# 1                             None  artificial intelligence  2023
# 2               [Computer Science]  artificial intelligence  2019
# 3               [Computer Science]  artificial intelligence  2017
# 4     [Computer Science, Medicine]  artificial intelligence  2019
# ...                            ...                      ...   ...
# 4495            [Computer Science]     large language model  2016
# 4496            [Computer Science]     large language model  2007
# 4497            [Computer Science]     large language model  2019
# 4498            [Computer Science]     large language model  2008
# 4499            [Computer Science]     large language model  2019
#
# [4500 rows x 7 columns]
